# %% [markdown]
# # Streaming
#
# ## Review
#
# In module 2, covered a few ways to customize graph state and memory.
#
# We built up to a Chatbot with external memory that can sustain long-running conversations.
#
# ## Goals
#
# This module will dive into `human-in-the-loop`, which builds on memory and allows users to interact directly with graphs in various ways.
#
# To set the stage for `human-in-the-loop`, we'll first dive into streaming, which provides several ways to visualize graph output (e.g., node state or chat model tokens) over the course of execution.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk

# %% [markdown]
# ## Streaming
#
# LangGraph is built with [first class support for streaming](https://docs.langchain.com/oss/python/langgraph/streaming).
#
# Let's set up our Chatbot from Module 2, and show various way to stream outputs from the graph during execution.

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("MISTRAL_API_KEY")

# %% [markdown]
# Note that we use `RunnableConfig` with `call_model` to enable token-wise streaming. This is [only needed with python < 3.11](https://langchain-ai.github.io/langgraph/how-tos/streaming-tokens/). We include in case you are running this notebook in CoLab, which will use python 3.x.

# %%
from IPython.display import Image, display
from typing import Literal

from langchain_mistralai import ChatMistralAI
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

# LLM
model = ChatMistralAI(model="mistral-medium", temperature=0) 


# State 
class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages, config)
    return {"messages": response}



def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State)-> Literal ["summarize_conversation", END]:
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer = memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Streaming full state
#
# Now, let's talk about ways to [stream our graph state](https://docs.langchain.com/oss/python/langgraph/streaming#supported-stream-modes).
#
# `.stream` and `.astream` are sync and async methods for streaming back results.
#
# LangGraph supports a few [different streaming modes](https://docs.langchain.com/oss/python/langgraph/streaming#stream-graph-state) for graph state.
#
# * `values`: This streams the full state of the graph after each node is called.
# * `updates`: This streams updates to the state of the graph after each node is called.
#
# ![values_vs_updates.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbaf892d24625a201744e5_streaming1.png)
#
# Let's look at `stream_mode="updates"`.
#
# Because we stream with `updates`, we only see updates to the state after node in the graph is run.
#
# Each `chunk` is a dict with `node_name` as the key and the updated state as the value.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start a conversation
for chunk in graph.stream(
    {
        "messages": [HumanMessage(content = "Hi am Abood!")]
    }, 
    config = config,
    stream_mode = "updates"):
    
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content='**Marhaba, Abood!** 😊\nHow are you today? How can I help you? Whether it’s learning something new, solving a problem, or just chatting—I’m here for you!\n\n(If you’d like, I can also respond in Arabic: **أهلاً وسهلاً يا أبو د! كيف ممكن أساعدك؟** 🇸🇦💙)', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 9, 'total_tokens': 98, 'completion_tokens': 89, 'prompt_tokens_details': {'cached_tokens': 0}}, 'model_name': 'mistral-medium', 'model': 'mistral-medium', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--019dafd4-151d-72b1-b39f-b0334d12608a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 89, 'total_tokens': 98})}}

# %% [markdown]
# Let's now just print the state update.

# %%
for chunk in graph.stream(
    {
        "messages": [HumanMessage(content = "Hi am Abood!")]
    }, 
    config = config,
    stream_mode = "updates"):
    chunk["conversation"]["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# **Marhaba, Abood!** 😊
# **How’s it going?** What’s on your mind today? Need help with something, or just saying hi? Either way—great to "meet" you!
#
# *(P.S. If you prefer Arabic: **أهلين يا أبو د! شلونك؟** 😄)*

# %% [markdown]
# Now, we can see `stream_mode="values"`.
#
# This is the `full state` of the graph after the `conversation` node is called.

# %%
config = {"configurable": {"thread_id": "2"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Abood")

for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event['messages']:
        m.pretty_print()
    print("---"*25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Abood
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Abood
# ================================== Ai Message ==================================
#
# Hi Abood! 😊 How are you doing today? How can I help you? Whether you need advice, answers, or just a fun chat—I'm here for it! 🚀
#
# (Also, *Abood* is a cool name! Is it short for something?)
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Streaming tokens
#
# We often want to stream more than graph state.
#
# In particular, with chat model calls it is common to stream the tokens as they are generated.
#
# We can do this [using the `.astream_events` method](https://docs.langchain.com/oss/python/langchain/models#advanced-streaming-topics:streaming-events), which streams back events as they happen inside nodes!
#
# Each event is a dict with a few keys:
#
# * `event`: This is the type of event that is being emitted.
# * `name`: This is the name of event.
# * `data`: This is the data associated with the event.
# * `metadata`: Contains`langgraph_node`, the node emitting the event.
#
# Let's have a look.

# %%
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="CS:GO Video Game")

async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    print(f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}")
# Out:
# Node: . Type: on_chain_start. Name: LangGraph
# Node: conversation. Type: on_chain_start. Name: conversation
# Node: conversation. Type: on_chat_model_start. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatMistralAI
# Node: conversation. Type: on_chat_model_end. Name: ChatMistralAI
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph

# %% [markdown]
# The central point is that tokens from chat models within your graph have the `on_chat_model_stream` type.
#
# We can use `event['metadata']['langgraph_node']` to select the node to stream from.
#
# And we can use `event['data']` to get the actual data for each event, which in this case is an `AIMessageChunk`.

# %%
node_to_stream = 'conversation'

config = {"configurable": {"thread_id": "4"}}

input_message = HumanMessage(content="CS:GO Video Game")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Counter-St', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='rike: Global', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Offensive', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (CS:', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='GO)** is a', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' highly popular **', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='first', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-person', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' shooter (F', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='PS)** game developed', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' by **Valve', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Corporation', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='** and **Hidden', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Path', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Entertainment', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**. It is', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the fourth', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' main', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' install', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ment in the *', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Counter-Strike*', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' series, following', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' *', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Counter', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-Strike ', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1.6', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='* and *Counter', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-Strike: Source', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='*.\n\n---\n\n', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='### **', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='🔫', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Game', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Overview', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**\n- **Release', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Date', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':** August', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 21,', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 201', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='2\n- **', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Platforms', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':** PC (Ste', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='am),', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' mac', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='OS,', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Linux,', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Xbox ', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='360 (', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='dis', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='continued', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='), PS', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='3 (', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='discontinued)\n-', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **Genre', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':** Tactical', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' F', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='PS (Comp', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='etitive', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' &', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Cas', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ual)\n- **', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Game', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' M', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='odes:**\n', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='  - **Comp', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='etitive (', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='v', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5)** – Bomb', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' def', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='usal', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='T', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='error', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ists', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' vs. Counter', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-T', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='errorists)\n ', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' - **Cas', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ual**', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' – Rel', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='axed', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' version', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of Compet', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='itive\n  -', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **Death', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='match', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='** – Fast', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-paced', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' respawn', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-based', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' combat', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n  - **', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Ar', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ms Race', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' &', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Dem', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='olition', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='** – Gun', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' progression', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' modes', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n  - **', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Wingman', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='2v2', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')** – Sm', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='aller', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-scale', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' competitive\n', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='  - **Danger', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Zone', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (Battle', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Royale', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')** – ', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='16', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-1', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='8 player', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' last', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-man', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-standing', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' mode\n  -', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **Community Serv', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers** – Custom', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' maps', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' &', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' game', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' modes (e.g', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='., *', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Sur', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='f,', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' K', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Z', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', Ret', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='akes', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', Zombie', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Escape', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='*)\n\n---\n\n### **', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='🎮', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Core', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Game', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='play**\n- **', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Teams', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':**\n', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='  - **T', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='errorists (T', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=')** – Plant', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the bomb', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' at one', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of two', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' sites', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.\n', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='  - **Counter', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-Terrorists (', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='CT)** – Def', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='use', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the bomb or', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' eliminate', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' all', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Ts', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.\n- **R', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ounds:**', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Best', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 3', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='0 (1', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5 rounds', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' per', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' half in', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Compet', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='itive).\n- **', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Economy System', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':**', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Players', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' earn money based on', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' performance to', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' buy weapons', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' armor, and utilities', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.\n- **We', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='apons:**\n', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='  - **R', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ifles', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (AK-', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='47, M', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4A', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4, A', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='WP', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' etc.)**\n ', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' - **Pist', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ols (Des', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ert', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Eagle, Glock', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', USP', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-S', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', etc.)**\n', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='  - **SM', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Gs (MP', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', U', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='MP-', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='45, P', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='0,', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' etc.)**\n ', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' - **Heavy', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Nova', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=', X', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# ...
# {'chunk': AIMessageChunk(content='- **CS', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':GO', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Wiki', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':**', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' [counter', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='st', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='rike.f', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='andom', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.com', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='](https://counter', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='strike.fandom', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.com/)\n\n---\n', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='### **', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='🚀 Final Thoughts', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**\nCS', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':GO (', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='now', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' CS2) remains', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' one', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of the **most', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' skill', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-based', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and rewarding', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' FPS games', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='** ever made', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='. Whether', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=" you're", additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' playing casually', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' friends or grinding', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' for **Global', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Elite**,', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' game', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' offers', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **end', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='less depth** and', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' excitement', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.\n\n**', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Want to improve', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='?', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**\n', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **P', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ractice aim', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' daily', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='** (A', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='im Lab', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Kova', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ak', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='’s).\n', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='- **Watch', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' your', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' dem', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='os** (Learn', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' from mistakes', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=').\n- **Play', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' with a team**', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (Communication', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' wins', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' games', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=').\n\n**', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Ready', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' drop in', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='?**', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' 🎮', additional_kwargs={}, response_metadata={'model_provider': 'mistralai'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='🔥', additional_kwargs={}, response_metadata={'model_provider': 'mistralai', 'model_name': 'mistral-medium', 'finish_reason': 'stop'}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 1626, 'total_tokens': 1634}, tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--019dafd4-b55b-7d42-8280-e606dea81901', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[], chunk_position='last')}

# %% [markdown]
# As you see above, just use the `chunk` key to get the `AIMessageChunk`.

# %%
config = {"configurable": {"thread_id": "5"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# |The| **San Francisco| 49|ers** are| one of the most| stor|ied| franch|ises in the **|National| Football League| (NFL)**,| known for their| rich| history|, legendary| players|, and five| **|Super Bowl championships|**.| Here’s a comprehensive| overview of the team|:
#
# ---
#
# ### **|🏆 Fran|chise| History &| Overview**
# - **|Founded|:** 19|4|6 (original|ly| in| the **All|-Amer|ica Football| Conference (|AAFC|)**| before joining the NFL| in 19|50).
# -| **Location|:** Santa| Clara|, California| (play| at| **Le|vi’s| Stadium** since| 201|4;| previously at| **Cand|l|estick Park|**).
# |- **Team Colors|:** **Sc|arlet| Red|, Gold, and| White**.
# |- **M|asc|ot:** **|Sourd|ough| Sam|** (a gold|-min|ing| prospect|or|).
# |- **Own|ership:** **|Denise| DeB|artolo| York| &| John York|** (since| 200|0).
# - **|Head Coach| (|2024|):** **K|yle Shan|ahan|** (since| 201|7).
# - **|General Manager|:** **John| Lynch|** (since |2017|).
#
# ---
#
# ### **|🏅| Championships| & Success**
# The| |49ers are| tied| for| **|3rd|-most| Super| Bowl wins| (5|)** in| NFL history|:
# 1|. **Super Bowl| XVI (19|81|)** – Beat| Cincinnati| Bengals| (2|6-|2|1)
#   | - **Co|ach:** Bill| Walsh|
#    - **|MVP:** Joe| Montana|
# 2. **|Super Bowl XIX| (1|984)**| – Beat Miami| Dolphins (3|8-1|6)
#    -| **MVP|:** Joe| Montana
# 3.| **Super Bowl XXIII| (1|988)**| – Beat Cincinnati| Bengals (2|0-1|6)
#    -| **MVP:** Jerry| Rice|
# 4|. **Super Bowl| XXIV| (198|9)** – Beat| Denver| Broncos (5|5-10|)
#    - **|MVP:** Joe Montana|
# 5. **|Super Bowl XX|IX (19|94)** –| Beat San| Diego Chargers (4|9-2|6)
#    -| **MVP:** Steve| Young|
#
# -| **N|FC Championships| (7|):** 19|81, |1984|, 19|88, |1989|, 19|94|, 2|012|, 20|19|
# - **Division| Tit|les (21|):** Most| recently| in **2|022|** (N|FC West|).
#
# ---
#
# ### **|🌟 Legendary| Players &| Co|aches**
# ####| **|🏈| Quarter|backs|**
# - **Joe| Montana** ("|The Come|back| Kid|") – 4|x Super| Bowl champ|, 3|x Super Bowl MVP|,| 2x NFL| MVP.
# - **|Steve Young** –| 1x Super| Bowl champ|, 2x| NFL MVP, left|-handed| scramb|ling QB|.
# - **Col|in| Kae|pernick|** – Led| the| 4|9ers to **|Super Bowl X|LV|II| (|2012|)** (|lost to| Ravens|).
# - **Jimmy| Gar|opp|olo|** – Hel|ped| reach| **|Super Bowl L|IV (20|19)** (|lost to Chiefs|).
# - **B|rock Pur|dy** ("|Mr|. Ir|relevant|") – Current starter|, led| team| to **N|FC Championship| (|202|2, 2|023)**|.
#
# #### **|🏃| Running| Back|s**
# - **|Roger Craig|** – First| RB| to have| **1,|000+| rushing| &| receiving| yards** in| a season| (198|5).
# - **|Frank Gore|** – Fran|chise’s| **all-time| leading r|usher** (1|1,0|7|3 yards|).
# - **Christian| McC|affrey|** (|current)| – Elite| dual|-threat| RB acquired| in| 202|2.
#
# #### **|🎯| Wide| Rece|ivers**
# |- **Jer|ry Rice** –| **GOAT| WR|**, 3|x Super Bowl champ|, NFL|’s| all-time leader| in receptions|, yards|, and TDs|.
# - **Ter|rell| Owens|** – Hall| of| Famer, played| key| role in| |1|990|s-|2000|s.
# - **|Deebo| Samuel|** (|current) – Dynamic| WR|/R|B hybrid|.
#
# |#### **|🛡|️ Defense|**
# - **Ron|nie L|ott** – Hall| of Fame| safety|, leader| of the **1|98|0s dynasty|**.
# - **Justin| Smith|** – Domin|ant| DE| in| the 20|00s.
# |- **Patrick| Willis|** – 7|x All|-Pro| line|backer (|200|7-|2014|).
# - **Fred| Warner|** (|current) – Elite| MLB|,| |2x| All-Pro.
# |- **Nick B|osa** (|current) – |20|22 Defensive Player| of the| Year, Super| Bowl L|VIII| (202|4) stand|out.
#
# ####| **|🧠| Coaches**
# -| **Bill Walsh|** – Architect| of| the **West| Coast| Off|ense**, 3|x Super Bowl winner|.
# - **George| Se|if|ert** – Won| **|2 Super Bow|ls (|198|9, 1|994)**|.
# - **Jim| Harb|augh** – Led| res|urgence| in| |2011|-|2014| (|Super| Bowl X|LVII appearance|).
# - **K|yle Shanahan**| – Current coach|, known| for offensive| innovation|.
#
# ---
#
# ### **|📈 Recent| Performance| (202|0s)**
# -| **201|9:**| **|Super Bowl L|IV**| (lost to| Chiefs,| 31|-20).
# |- **20|21|-202|3:** Strong| regular| seasons but| playoff| struggles| (lost| in| **N|FC Championship |3| times|**).
# - **|2023| Season|:**
# |  - **1|2-|5 record|**, **|NFC West| champs|**.
#   - **|Super| Bowl LVIII| (202|4)** – Lost| to **Kansas| City| Chiefs (25|-22| OT|)** in a| thr|illing game|.
#  | - **Brock| Purdy** emerged| as a top| QB|,| **Christian| McCaff|rey** was| MVP| candidate|.
#
# ---
#
# ### **|🏟|️ Home| Stadium:| Levi|’s Stadium**
# -| **Opened:** |2014| (|re|placed Cand|lestick Park|).
# - **Capacity|:** ~|68|,5|00.
# -| **Not|able Features|:**
# |  - Host|ed **|Super Bowl |50 (|2016|)**.
#   -| Known| for **tech| innovations|** (Wi|-Fi|, mobile| ticket|ing).
#   -| Crit|icized| for **poor| field| conditions** in| early| years.
#
# ---
#
# ###| **|🤝| Rival|ries|**
# 1|. **D|allas Cowboys|** – Historic| **198|0s-|9|0s NFC| battles|** (Mont|ana| vs. A|ik|man|).
# 2|. **Seattle| Seahawks** – **|NFC West| rivals|**,| intense| games| (|e|.g., |2013| NFC| Championship).
# |3. **Los| Angeles Rams** –| Division| rivals|, playoff| clashes| (|2|02|1 NFC Championship|).
# 4. **|Green Bay| Packers** – Classic| match|ups| (Young| vs|. Favre| in| the 19|90s).
#
# |---
#
# ### **|📊| Key| Records| & Stats**
# -| **Most| Pass| TD|s in| a Game|:**| **6|** (Joe| Montana, Steve| Young,| Nick| Mull|ens|).
# - **Most| Receiving| TD|s in a Season|:** **|22|** (Jer|ry Rice, |198|7|).
# - **Long|est Win| Stre|ak:** **|18| games| (|198|9-|1990|)**.
# - **|All-Time Leading| Sc|orer|:** **Jer|ry Rice (|1|,1|3|3| points|)**.
#
# ---
#
# ###| **|🎭| Pop| Culture & Legacy|**
# - **"|The Catch|" (19|81| NFC| Championship)** – Joe| Montana to| **|Dwight| Clark|** vs|. Cowboys| (icon|ic moment|).
# - **"|The Catch II|" (1|998| Wild| Card|)** – Steve| Young to **Ter|rell Owens|** vs|. Packers|.
# - **Col|in| Kaepernick|’s Protest| (201|6)** – Kne|eling| during the national| anthem sparked| nationwide| debates.
# - **|Document|aries|:** *|ES|PN| |30 for| 30:| "The '|8|5| Bears| vs|. The| '|9|4| |4|9ers"*| (h|ypothetical| matchup|).
#
# ---
#
# ### **|🔮| |2024| Outlook| & Future**
# -| **Strengths|:**
# |  - **El|ite roster|** (P|urdy, Mc|Caffrey,| Deebo|, K|ittle|, Bosa|, Warner|).
#   - **|Strong coaching|**| (Sh|anahan’s| offensive scheme|).
# -| **Ch|allenges:**
#  | - **Super| Bowl hang|over|?**| (Lost| |3| straight| NFC title| games before| 202|3|).
#   - **|Salary cap| management|** (key| players like| **|Br|andon| A|iy|uk|** need| contracts|).
# - **Draft| &| Free| Agency|:** Focus on **|def|ensive depth|**| and **WR| corps|**.
#
# ---
# ### **|📌| Fun| F|acts**
# - **|Name Origin|:** Named| after the| **18|4|9 California| Gold Rush|** miners| ("|49ers|").
# - **First| Team| to| Win| 5| Super Bowls|** (t|ied with Cowboys| & Patriots|).
# - **Only| Team| to Go| 15|-1 in| Back|-to|-Back Seasons (|198|4|,| 198|5)**.
# -| **Jer|ry Rice holds| the| record| for most| Super| Bowl TD|s (8|)**.
#
# |---
# ### **|🔗 Where| to Follow|**
# - **Website|:** [www|.4|9ers.com](|https://www.|49ers.com|)
# - **Social| Media:** @|4|9ers (Twitter|/|Instagram)
# |- **Pod|casts|:** *|49ers| Web|zone|,| The| |49ers Ins|ider Pod|cast*
#
# ---
# ###| **|🏈| Final Thoughts|**
# The |49ers are| a **blue|-b|lood franchise** with| a **winning| tradition|**, known| for **inn|ovative off|enses|**| (|West| Coast Off|ense) and **|dominant defenses|**. After| a| **dec|ade| of rebuilding|**, they|’re back as| **|Super Bowl cont|enders**| with| a| **you|ng core|** led| by **B|rock Purdy and| Kyle Shan|ahan**. The **|2024| season|** will be| crucial as| they aim| to **end| their| 3|0-year championship drought|**.
#
# Would you like| details on a| specific era|, player, or| season|?||

# %%
node_to_stream = 'conversation'

config = {"configurable": {"thread_id": "6"}}

input_message = HumanMessage(content="CS:GO Video Game")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"]["chunk"].content, end="|")
# Out:
# |**|Counter-St|rike: Global| Offensive| (CS:|GO)** is a| highly popular **|first|-person| shooter (F|PS)** game developed| by **Valve| Corporation|** and **Hidden| Path| Entertainment|**. It is| the fourth| main| install|ment in the *|Counter-Strike*| series, following| *|Counter|-Strike:| Source*| (2|004|).
#
# |### **Key Features| of CS:GO|**
# 1. **|Gameplay M|odes**
#    -| **Comp|etitive| (|5|v|5):** The most| popular mode|, where| two| teams (|Terror|ists vs. Counter|-Terror|ists) compete| in a best|-of|-30-round| match.
#    -| **Cas|ual:**| A| more relaxed version| of Compet|itive with fewer| rounds| and| less| strict| rules|.
#    - **|Deathmatch|:** Fast|-paced| respawn|-based| mode for| practicing| gun|play|.
#    - **|Ar|ms Race| &| Dem|olition|:** Fun|, progression-based modes| with weapon| upgrades.
#    -| **Wingman| (|2v2):**| A smaller-scale| competitive| mode| on compact| maps|.
#    - **|Danger Zone| (Battle| Royale|):** A |16|-|18 player last|-man|-standing mode (less| popular now|).
#
# 2. **|Maps|**
# |   - Classic| maps like| **D|ust II|, Mirage|, Infer|no|, Nu|ke|, Over|pass|, Vert|igo|, and Ancient|** are stap|les| in competitive play|.
#    - Community|-|created maps (|e.g., **|Cache, Cob|bl|estone**) are also| available.
#
# |3. **E|conomy| System**
#    -| Players earn| in|-game money| based on performance| (|k|ills, objectives|, round wins/|losses|).
#    - Money| is used to buy| weapons|, armor|, gren|ades, and utility| (sm|okes, flash|b|angs, etc.).
# |   - Managing| the economy| is a key| strategic| element|.
#
# 4|. **Weapons| & Equipment|**
#    - **|Rifles|:** AK|-4|7 (T|), M4|A4|/M4A|1-S| (CT|)
# |   - **Sn|ipers|:** A|WP|,| SS|G |08,| Scout|
#    - **|SM|Gs:** MP|9|, U|MP-|45, P|9|0
#    -| **Pist|ols:** Desert| Eagle|, Glock|-|18, USP|-S|,| P2|50
#   | - **Heavy|:**| Nova| (|shot|gun|), Ne|gev| (LM|G|)
#    - **|G|renades:** Flash|bangs|, HE Gren|ades, Smokes|, Mol|otov|s/|Incendi|ary|,| Dec|o|ys
#
# 5.| **Ranking| System (|Competitive Match|making|)**
#    - Players| are| ranked from **Silver| I| (low|est)| to Global| Elite (high|est)**.
#   | - A| **|hidden| E|LO-based| system** determines| rank| changes| after| matches|.
#    - **|Prime| Matchmaking|** (requires| a Prime| upgrade|)| offers| better match quality|.
#
# 6. **|Esports| & Professional| Scene**
#    -| CS:GO is| one of the **|biggest es|ports titles|**, with major| tournaments like:
# |     - **Maj|ors (|Valve|-s|ponsored,| $1M|+ prize| pools|)**
#      - **|ESL Pro| League|, B|LAST| Premier|, I|EM| (|Int|el Extreme| Masters)**
#   | - Top| teams: **Fa|Ze| Clan|, Natus| Vinc|ere| (Na|’|Vi), Team| Vital|ity|, G2| Es|ports, Astr|alis|**
#    - Legend|ary players: **|s1|m|ple, Z|yw|O|o, device|, cold|z|era, sh1|ro|**
#
# 7|. **Sk|illing| & Mechanics|**
#    - **|Aim| Training|:** Sp|ray control|, flick| shots|, cross|hair| placement.
#    -| **Movement:**| Counter|-st|raf|ing, bun|ny| hop|ping, pe|eking| techniques|.
#    - **|Utility Usage|:** Smokes|, flashes|, and mol|otov|s for map control|.
#    - **|Game Sense|:** Position|ing, rotations|, reading| opponents|.
#
# 8. **|Custom Content| & Community**
#   | - **Work|shop| Maps|:**| Players| can create and| share| custom maps.
#   | - **Community| Serv|ers:** Sur|f, K|Z| (|mov|ement|), Ret|akes|, |1v|1 Ar|enas.
#    -| **Skin| Economy|:** Cos|metic| weapon| skins (some| worth| thousands| of| dollars).
#
# 9.| **CS|2| (|Counter|-Strike |2) – The| Future|**
#    - **|CS:|GO is| being replaced by *|Counter-Strike |2* (CS|2)**, a| major update| built| on **Source| 2 engine|** (|released **|September 27|, 20|23**).
# |   - Features| **|improved graphics|, dynamic| smoke|, sub-tick| servers|, and better physics|**.
#
# |---
#
# ### **How| to Get| Started in| CS:GO (|or| CS2)**
# 1|. **Download| &| Install|**
#    - Available| on| **Steam (|Free-to|-|Play since| 201|8)**.
#   | - [|Ste|am Store Page|](https://store|.steamp|ower|ed.com|/app/7|3|0/C|ounterSt|rike_Global_O|ff|ensive/)
#
# |2. **Learn| the| Basics**
#   | - Play **Death|match** to| improve aim|.
#    - Try| **Cas|ual** before| jumping| into **Compet|itive**.
#    -| Watch **pro| players|**| (Tw|itch/|YouTube) to| learn strategies|.
#
# 3. **|Improve| Your Skills|**
#    - **|Aim Training|:** Use **A|im Lab|,| Kova|ak|’s,| or CS|:GO’s| Workshop| maps|**.
#    - **|Sp|ray Control|:** Practice| reco|il| patterns in| an| empty server|.
#    - **|Map| Knowledge|:** Learn call|outs, smokes|, and flashes| for| key| maps.
#
# 4|. **Join| the Community**
#   | - **Reddit|:** r/Global|Off|ensive
#    -| **Discord Serv|ers:** Many| CS:|GO communities for tips| and| team|ing| up|.
#    - **|Face|it|/E|SEA|:** Third|-party platforms for better| matchmaking|.
#
# 5|. **Upgrade| to Prime| (Optional|)**
#    - **|Prime Status|** (|one|-time purchase or| by| reaching Level| 21|) gives|:
# |     - Better match|making (f|ewer che|aters|).
#      - Ex|clusive item| drops.
#      -| Prime|-only| competitive| queue|.
#
# ---
#
# ### **|CS:GO vs|. CS|2| –| What’s| Changing|?**
# || Feature|         | | CS|:GO | CS|2 |
# |----------------|--|----|---|-----||
# | **Engine|**      | | Source| || Source |2 |
# | **|Graphics**    | | Out|dated | Modern| (|better| lighting, textures|) |
# | **|Smoke**       | | Static || Dynamic| (react|s| to environment|)| |
# | **Tick| Rate|**   | | 6|4-t|ick (MM|),| 128|-tick (Face|it) | **|Sub-tick**| (more| responsive|) |
# | **|Movement|**    | | Classic| | S|mo|other,| better| physics |
# | **|Maps**        | | Same|,| but updated| | Some re|works| (e.g.,| Dust II|, Mirage|)| |
# | **Anti|-C|heat|**  | | V|AC +| Overwatch | **|VAC Live| (|better| che|at detection|)** |
#
# ---
#
# ###| **Final| Thoughts**
# CS|:GO is a| **high|ly skill|-based,| tactical F|PS** with a| **th|riving| competitive| scene|**. Whether| you're| playing| casually| or aiming| for pro| level|, master|ing **|aim|, game| sense|, and team|work** is key|.
#
# With| **CS|2**| now out|, the game| is evolving|,| but the core| **|Counter|-Strike experience|** remains the| same.
#
# |**|Want to improve|?**
# - **|Practice aim| daily|.**
# |- **Learn| utility| (|smokes|, flashes|).**
# - **|Watch pro| matches| (HL|TV|.org|).**
# - **|Play with a| team (communication| wins| games|).**
#
# Would you| like recommendations for| **training| maps|, config| settings, or pro| player| streams|**?||

# %% [markdown]
# ### Streaming with LangGraph API
#
# **⚠️ Notice**
#
# Since filming these videos, we've updated Studio so that it can now be run locally and accessed through your browser. This is the preferred way to run Studio instead of using the Desktop App shown in the video. It is now called _LangSmith Studio_ instead of _LangGraph Studio_. Detailed setup instructions are available in the "Getting Setup" guide at the start of the course. You can find a description of Studio [here](https://docs.langchain.com/langsmith/studio), and specific details for local deployment [here](https://docs.langchain.com/langsmith/quick-start-studio#local-development-server).
# To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the **Studio UI** URL shown above.
#
# The LangGraph API  [supports editing graph state](https://docs.langchain.com/langsmith/add-human-in-the-loop).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client

# This is the URL of the local development server
URL = "http://127.0.0.1:2024"
client = get_client(url=URL)

# Search all hosted graphs
assistants = await client.assistants.search()

# %% [markdown]
# Let's [stream `values`](https://docs.langchain.com/oss/python/langgraph/streaming#stream-graph-state), like before.

# %%
# Create a new thread
thread = await client.threads.create()
# Input message
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="values"):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '019a0358-31b4-7143-af47-2feeac0b27ce', 'attempt': 1})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '9aaa247f-1e6e-4451-af25-ac678fe46d82'}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '9aaa247f-1e6e-4451-af25-ac678fe46d82'}, {'content': '', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_eb3c3cb84d', 'id': 'chatcmpl-CSqw4HhOXHahA4tIr4mIdEhQB1QB4', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--4a3794f6-52c3-41b5-9620-1710d6e8392d-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_3sCWZZ89AoUe91MYc3ZBtJ0P', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '9aaa247f-1e6e-4451-af25-ac678fe46d82'}, {'content': '', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_eb3c3cb84d', 'id': 'chatcmpl-CSqw4HhOXHahA4tIr4mIdEhQB1QB4', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--4a3794f6-52c3-41b5-9620-1710d6e8392d-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_3sCWZZ89AoUe91MYc3ZBtJ0P', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'f05da6b3-27be-4896-967a-3ff60aa06d85', 'tool_call_id': 'call_3sCWZZ89AoUe91MYc3ZBtJ0P', 'artifact': None, 'status': 'success'}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '9aaa247f-1e6e-4451-af25-ac678fe46d82'}, {'content': '', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_eb3c3cb84d', 'id': 'chatcmpl-CSqw4HhOXHahA4tIr4mIdEhQB1QB4', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--4a3794f6-52c3-41b5-9620-1710d6e8392d-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_3sCWZZ89AoUe91MYc3ZBtJ0P', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'f05da6b3-27be-4896-967a-3ff60aa06d85', 'tool_call_id': 'call_3sCWZZ89AoUe91MYc3ZBtJ0P', 'artifact': None, 'status': 'success'}, {'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 14, 'prompt_tokens': 159, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_eb3c3cb84d', 'id': 'chatcmpl-CSqw4xk8t3sPODL5beks5TlJBozgB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--33a25ab0-f748-4c7f-a086-d9249e25fdc0-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 159, 'output_tokens': 14, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]})

# %% [markdown]
# The streamed objects have:
#
# * `event`: Type
# * `data`: State

# %%
from langchain_core.messages import convert_to_messages
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], assistant_id="agent", input={"messages": [input_message]}, stream_mode="values"):
    messages = event.data.get('messages',None)
    if messages:
        print(convert_to_messages(messages)[-1])
    print('='*25)

# %% [markdown]
# There are some new streaming mode that are only supported via the API.
#
# For example, we can  [use `messages` mode](https://docs.langchain.com/oss/python/langgraph/streaming#supported-stream-modes) to better handle the above case!
#
# This mode currently assumes that you have a `messages` key in your graph, which is a list of messages.
#
# All events emitted using `messages` mode have two attributes:
#
# * `event`: This is the name of the event
# * `data`: This is data associated with the event

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="messages"):
    print(event.event)
# Out:
# metadata
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/metadata
# messages/complete
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial

# %% [markdown]
# We can see a few events:
#
# * `metadata`: metadata about the run
# * `messages/complete`: fully formed message
# * `messages/partial`: chat model tokens
#
# <!--You can dig further into the types [~here~](https://langchain-ai.github.io/langgraph/cloud/concepts/api/#modemessages) [here](https://docs.langchain.com/oss/python/langgraph/concepts/langgraph_server). -->
#
# Now, let's show how to stream these messages.
#
# We'll define a helper function for better formatting of the tool calls in messages.

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")

def format_tool_calls(tool_calls):
    """
    Format a list of tool calls into a readable string.

    Args:
        tool_calls (list): A list of dictionaries, each representing a tool call.
            Each dictionary should have 'id', 'name', and 'args' keys.

    Returns:
        str: A formatted string of tool calls, or "No tool calls" if the list is empty.

    """

    if tool_calls:
        formatted_calls = []
        for call in tool_calls:
            formatted_calls.append(
                f"Tool Call ID: {call['id']}, Function: {call['name']}, Arguments: {call['args']}"
            )
        return "\n".join(formatted_calls)
    return "No tool calls"

async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input={"messages": [input_message]},
    stream_mode="messages",):
    
    # Handle metadata events
    if event.event == "metadata":
        print(f"Metadata: Run ID - {event.data['run_id']}")
        print("-" * 50)
    
    # Handle partial message events
    elif event.event == "messages/partial":
        for data_item in event.data:
            # Process user messages
            if "role" in data_item and data_item["role"] == "user":
                print(f"Human: {data_item['content']}")
            else:
                # Extract relevant data from the event
                tool_calls = data_item.get("tool_calls", [])
                invalid_tool_calls = data_item.get("invalid_tool_calls", [])
                content = data_item.get("content", "")
                response_metadata = data_item.get("response_metadata", {})

                if content:
                    print(f"AI: {content}")

                if tool_calls:
                    print("Tool Calls:")
                    print(format_tool_calls(tool_calls))

                if invalid_tool_calls:
                    print("Invalid Tool Calls:")
                    print(format_tool_calls(invalid_tool_calls))

                if response_metadata and response_metadata.get("finish_reason"):
                    print(f"Response Metadata: Finish Reason - {response_metadata['finish_reason']}")                    
        print("-" * 50)
# Out:
# Metadata: Run ID - 019a0358-57dc-76f9-bc63-633eee467a86
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {'a': 2, 'b': 3}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {'a': 2, 'b': 3}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - tool_calls
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - tool_calls
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_mDtKBiuzkpN5ITWykhEFN0XU, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - tool_calls
# --------------------------------------------------
# --------------------------------------------------
# AI: The
# --------------------------------------------------
# AI: The result
# --------------------------------------------------
# AI: The result of
# --------------------------------------------------
# AI: The result of multiplying
# --------------------------------------------------
# AI: The result of multiplying
# --------------------------------------------------
# AI: The result of multiplying 2
# --------------------------------------------------
# AI: The result of multiplying 2 and
# --------------------------------------------------
# AI: The result of multiplying 2 and
# --------------------------------------------------
# AI: The result of multiplying 2 and 3
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6.
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
